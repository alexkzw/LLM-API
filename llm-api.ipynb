# %%
# LangChain Implementation with TogetherAI using LLM Chain with Chain of Thought (CoT) and Few-Shot Learning
import os
import together
from pathlib import Path
from pypdf import PdfReader
from typing import List, Dict
from langchain_core.runnables import RunnableSequence
from langchain_core.prompts import PromptTemplate, FewShotPromptTemplate
from langchain.llms.base import LLM
from pydantic import BaseModel, Field
from __future__ import annotations

# %%
# Prompt Template with Few‑Shot Learning and Validation/Refinement Pipeline
"""
This module implements a complete question‑answering pipeline that
  1. Builds a few‑shot prompt from simple Q‑A pairs that come only from the
     reference PDF (the impact of artificial intelligence – an economic analysis).
  2. Generates an answer that must stay grounded in that reference.
  3. Runs a validator chain to label each claim as SUPPORTED / UNSUPPORTED / PARTIALLY SUPPORTED.
  4. Iteratively refines the answer (up to 5 passes) until no unsupported claims remain.
  5. If unsupported claims persist after 5 iterations, the best attempt is returned along with
     a message stating that the maximum refinement depth has been reached.
The code is based on LangChain and uses Together AI as the inference provider
"""

# LLM SET‑UP -----------------------------------------------------------
# Setup TogetherAI client

# modify TogetherAI Free API Key as required below
api_key = "e5cb3bf0234845ccad2fdd134cd4224691d2e0da722818509d301fdaf36afc6b"
client = together.Together(api_key=api_key)
MODEL_NAME = "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo"

# %%
# Custom LLM Class to Integrate TogetherAI with LangChain
class TogetherAI_LLM(LLM):

    # define model name as a pydantic field
    model_name: str = Field(default=MODEL_NAME)

    # method for handling sending prompts to TogetherAI LLM & retrieving responses
    def _call(self, prompt: str, stop: List[str] = None) -> str:
        response = client.chat.completions.create(
            model=self.model_name,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
            max_tokens=2000
        )
        return response.choices[0].message.content

    # identifies the LLM type as together-ai
    @property
    def _llm_type(self) -> str:
        return "together-ai"

# Create an instance of TogetherAI LLM class for use in prompt chains
together_llm = TogetherAI_LLM()

# %%
# Function to extract text from PDF
def get_pdf_text(file_path: str) -> str:
    text = ""
    try:
        with Path(file_path).open("rb") as f:
            reader = PdfReader(f)
            text = "\n\n".join([page.extract_text() for page in reader.pages])
    except Exception as e:
        raise Exception(f"Error reading the PDF file: {str(e)}")

    if len(text) > 400_000:
        raise Exception("PDF too long. Limit to 131072 characters.")
    return text

# %%
# Few‑shot examples (not one of the evaluation prompts )
# All examples are deliberately *simple* factual snippets lifted from the
# reference PDF so that the LLM gets a clear style/format to imitate.
example_prompt = PromptTemplate.from_template(
    "Question: {question}\nAnswer: {answer}"
)

examples: List[Dict[str, str]] = [
    {
        "question": "What is 'Artificial Intelligence' from an economic perspective?",
        "answer": (
            "The reference document (the impact of artificial intelligence – an economic analysis) defines AI as the capability of "
            "machines to perform tasks that would typically require a human, like reasoning or problem solving, learning, and perception. "
        ),
    },
    {
        "question": "What is one of the factors identified as contributing to New Zealand's slow diffusion of new technology?",
        "answer": (
            "Inflexible or outdated regulations: regulatory systems that have been cited as problematic include data access "
            "competition policy, genetic modification controls, and land use policy (New Zealand Productivity Commission, 2020). "
            "as stated by the reference document. "
        ),
    },
    {
        "question": "What is 'so-so automation'?",
        "answer": (
            "'so-so automation' refers to automation that reduces wages without significant productivity gains "
            "- self-checkouts in grocery stores being one example. "
        ),
    },
]

# %%
# Initial few-shot prompt ---------------------------------------------
prefix = (
    "You are an assistant with access to the following reference document.\n"
    "Answer ONLY from this reference – cite nothing else and do not guess.\n\n"
    "Reference (verbatim extract):\n{reference}\n\n"  # passed in at runtime
)

suffix = (
    "\nQuestion: {prompt}\nAnswer:"  # {prompt} supplied at runtime
)

# Define the initial few-shot prompt template used to generate the first LLM response.
# - prefix: introductory instructions and the reference document content.
# - suffix: appends the user’s question after the few-shot examples.
# - examples: a list of simple question-answer pairs extracted from the reference document.
# - example_prompt: the format for rendering each example.
# - input_variables: specifies which fields are dynamically passed in at runtime.
initial_prompt_template: FewShotPromptTemplate = FewShotPromptTemplate(
    prefix=prefix,
    suffix=suffix,
    examples=examples,
    example_prompt=example_prompt,
    input_variables=["reference", "prompt"],
)

# %%
# Validation & refinement -----------------------------------
validation_prompt_template = PromptTemplate(
    input_variables=["reference", "response"],
    template=(
        "You are a fact‑checking assistant. For EACH factual claim in the response, "
        "state whether it is SUPPORTED, UNSUPPORTED, or PARTIALLY SUPPORTED by "
        "the reference.\n\nReference:\n{reference}\n\nResponse:\n{response}\n\n"
        "Return a bullet list of labelled claims followed by an overall verdict."
    ),
)

refinement_prompt_template = PromptTemplate(
    input_variables=["reference", "response"],
    template=(
        "The previous answer contained unsupported claims. Using ONLY the reference "
        "below, rewrite the answer so that every statement is fully supported. "
        "If a point cannot be supported, omit it.\n\nReference:\n{reference}\n\n"
        "Current answer:\n{response}\n\nRevised answer:"),
)

# %%
# Executes a LangChain prompt by piping the prompt template into the TogetherAI LLM.
# Returns the generated response based on the provided inputs.
def run_llm_chain(prompt_template, inputs: dict) -> str:
    runnable = prompt_template | together_llm
    return runnable.invoke(inputs)

# %%
def iterative_refinement_chain(reference: str, draft_answer: str) -> str:
    max_iterations = 5
    for i in range(max_iterations):
        validation_result = run_llm_chain(
            validation_prompt_template,
            {"reference": reference, "response": draft_answer},
        )
        print(f"\n[Iteration {i+1} Validation Result]:\n{validation_result}\n")

        if "UNSUPPORTED" not in validation_result and "PARTIALLY SUPPORTED" not in validation_result:
            print("All claims supported. No refinement needed.")
            return draft_answer

        print("Unsupported claims found. Refining response...")
        draft_answer = run_llm_chain(
            refinement_prompt_template,
            {"reference": reference, "response": draft_answer},
        )
    print("Maximum iterations reached. Returning best attempt.")
    return draft_answer

# %%
# Execution pipeline ------------------------------------------------------------
def run_pipeline(reference_path: str | Path, prompts: List[str]):
    reference_content = get_pdf_text(reference_path)

    for i, prompt in enumerate(prompts, start=1):
        print(f"\n=== Prompt {i} ===\n{prompt}\n")
        initial_answer = run_llm_chain(
            initial_prompt_template,
            {"reference": reference_content, "prompt": prompt},
        )
        final_answer = iterative_refinement_chain(reference_content, initial_answer)
        print(f"Final Answer {i}:\n{final_answer}\n")

# default LLM response without in-context learning w.r.t reference document
def run_llm_without_reference(prompt: str) -> str:
    return together_llm.invoke(prompt)

# %%
if __name__ == "__main__":
    test_prompt = "What is the predicted global economic impact of AI on employment?"
    print(f"Default Response without Reference:\n{run_llm_without_reference(test_prompt)}")

    reference_path = "impact-of-ai-an-economic-analysis.pdf"
    test_prompts = [
        "What is the predicted global economic impact of AI on employment?",
        "How will AI influence wage inequality globally?",
        "What regulatory challenges are anticipated with AI adoption?",
        "How will AI adoption differ across regions and countries?",
        "What industries are most likely to be disrupted by AI according to the report?"
    ]
    run_pipeline(reference_path, test_prompts)
# Out:
# Default Response without Reference:
# The predicted global economic impact of AI on employment is a complex and multifaceted topic. While AI has the potential to bring significant benefits, such as increased productivity and efficiency, it also poses significant challenges for workers and the labor market. Here are some predictions and estimates:
#
# 1. **Job displacement**: According to a report by the McKinsey Global Institute, up to 800 million jobs could be lost worldwide due to automation by 2030. Another report by the World Economic Forum estimates that by 2022, more than a third of the desired skills for most jobs will be comprised of skills that are not yet considered crucial to the job today.
# 2. **Job creation**: However, while AI may displace some jobs, it is also expected to create new ones. A report by the World Economic Forum estimates that by 2022, 75 million jobs may be displaced by automation, but 133 million new jobs may be created.
# 3. **Net job loss**: Despite the creation of new jobs, the net impact of AI on employment is still expected to be negative. A report by the Institute for Public Policy Research estimates that the UK alone could lose up to 20% of its workforce to automation by 2030.
# 4. **Skills shift**: AI is expected to change the skills required for many jobs. A report by the McKinsey Global Institute estimates that by 2030, 60% of occupations will require skills that are not yet considered crucial to the job today.
# 5. **Industry impact**: Some industries are expected to be more heavily impacted by AI than others. For example, a report by the International Labor Organization estimates that the manufacturing sector could lose up to 30% of its workforce to automation by 2030.
#
# **Predicted impact by sector:**
#
# 1. **Transportation**: 50-70% of jobs could be displaced by automation (e.g., self-driving cars).
# 2. **Manufacturing**: 30-50% of jobs could be displaced by automation (e.g., robotics).
# 3. **Customer service**: 30-50% of jobs could be displaced by automation (e.g., chatbots).
# 4. **Bookkeeping and accounting**: 20-30% of jobs could be displaced by automation (e.g., automated accounting software).
# 5. **Healthcare**: 10-20% of jobs could be displaced by automation (e.g., medical imaging analysis).
#
# **Key regions:**
#
# 1. **Asia-Pacific**: Expected to be heavily impacted by AI, with up to 50% of jobs displaced in some countries (e.g., China, Japan).
# 2. **Europe**: Expected to be moderately impacted, with up to 30% of jobs displaced (e.g., UK, Germany).
# 3. **North America**: Expected to be relatively less impacted, with up to 20% of jobs displaced (e.g., US, Canada).
#
# **Mitigating the impact:**
#
# 1. **Upskilling and reskilling**: Governments, educational institutions, and employers can invest in programs that help workers develop new skills.
# 2. **Social safety nets**: Governments can implement policies to support workers who lose their jobs due to automation, such as basic income guarantees or job retraining programs.
# 3. **Encouraging entrepreneurship**: Governments can create an environment that encourages entrepreneurship and innovation, which can lead to the creation of new jobs.
#
# Overall, the predicted global economic impact of AI on employment is complex and multifaceted. While AI has the potential to bring significant benefits, it also poses significant challenges for workers and the labor market.
#
# === Prompt 1 ===
# What is the predicted global economic impact of AI on employment?
#
#
# [Iteration 1 Validation Result]:
# * Claim 1: Advanced economies like New Zealand are more vulnerable to AI's employment impacts compared to emerging economies.
#   Verdict: SUPPORTED (Georgieff and Hyee, 2021; Briggs and Kodnani, 2023)
# * Claim 2: The predicted global economic impact of AI on employment is not explicitly stated in the provided snippet.
#   Verdict: UNSUPPORTED
#
# Unsupported claims found. Refining response...
#
# [Iteration 2 Validation Result]:
# Here's a list of labelled claims with their respective verdicts based on the reference:
#
# • **Claim 1: AI can be considered both a "General Purpose Technology" (GPT) and an "Invention of a Method of Invention" (IMI).** (SUPPORTED)
# This claim is supported by the reference, which states that AI can be thought of as both a GPT and an IMI.
#
# • **Claim 2: AI can be thought of as a form of capital deepening, improving the quantity and quality of capital inputs.** (SUPPORTED)
# This claim is supported by the reference, which states that AI can be thought of as a form of capital deepening.
#
# • **Claim 3: AI can be thought of as labor-augmenting technology that improves the quality of labor inputs.** (SUPPORTED)
# This claim is supported by the reference, which states that AI can be thought of as labor-augmenting technology.
#
# • **Claim 4: AI can be seen as a form of workplace automation.** (SUPPORTED)
# This claim is supported by the reference, which states that AI can be seen as a form of workplace automation.
#
# • **Claim 5: AI can lead to a 1.5% annual increase in labor productivity growth.** (PARTIALLY SUPPORTED)
# This claim is partially supported by the reference, which states that Briggs and Kodnani (2023) suggest a 1.5% annual increase in labor productivity growth, but this is based on a specific study and not a universal conclusion.
#
# • **Claim 6: AI can lead to a 40% reduction in time taken to produce a piece of writing and an 18% increase in quality.** (PARTIALLY SUPPORTED)
# This claim is partially supported by the reference, which states that Noy and Zhang (2023) found that ChatGPT increased productivity by reducing the time taken to produce a piece of writing by 40% and increasing the quality by 18%, but this is based on a specific study and not a universal conclusion.
#
# • **Claim 7: AI can lead to so-so automation, reducing wages without significant productivity gains.** (PARTIALLY SUPPORTED)
# This claim is partially supported by the reference, which states that Acemoglu and Restrepo (2022) report that AI could contribute to so-so automation, but this is based on a specific study and not a universal conclusion.
#
# • **Claim 8: AI can lead to a narrowing of the productivity gap between higher-skilled and lower-skilled workers.** (PARTIALLY SUPPORTED)
# This claim is partially supported by the reference, which states that Brynjolfsson et al. (2023) emphasize that AI might narrow the productivity gap between higher-skilled and lower-skilled workers, but this is based on a specific study and not a universal conclusion.
#
# • **Claim 9: New Zealand's regulatory approach for AI will need to consider the implications for Māori and Te Tiriti o Waitangi.** (SUPPORTED)
# This claim is supported by the reference, which states that New Zealand's regulatory approach for AI will need to consider the implications for Māori and Te Tiriti o Waitangi.
#
# **Overall Verdict:** The reference provides a detailed analysis of the impact of AI on the economy, including its potential benefits and challenges. While some claims are universally supported, others are partially supported based on specific studies and not universal conclusions.
#
# Unsupported claims found. Refining response...
#
# [Iteration 3 Validation Result]:
# Here's a bullet list of labelled claims followed by an overall verdict:
#
# • "AI can be considered both a 'General Purpose Technology' (GPT) and an 'Invention of a Method of Invention' (IMI)." (SUPPORTED, Reference: Cockburn et al. (2019))
#
# • "AI can be thought of as a form of capital deepening, improving the quantity and quality of capital inputs." (SUPPORTED, Reference: Macroeconomic frameworks: AI and aggregate production functions)
#
# • "AI can be seen as a form of workplace automation." (SUPPORTED, Reference: Microeconomic frameworks: AI and the allocation of tasks in production)
#
# • "Estimates suggest significant potential for productivity gains from AI, and from generative AI in particular." (SUPPORTED, Reference: Briggs and Kodnani (2023), Chui et al. (2023))
#
# • "The net impact of AI on labor demand and share depends on the balance between displacement and reinstatement." (SUPPORTED, Reference: Acemoglu and Restrepo (2019))
#
# • "The short-term employment impacts of AI might be modest, with around 7% of workers in the United States being fully displaced, but most finding new employment in only slightly less productive positions." (SUPPORTED, Reference: Briggs and Kodnani (2023))
#
# • "There is a consensus on the principles that should govern AI, including human control, transparency, safety, accountability, non-discrimination, and privacy." (SUPPORTED, Reference: Fjeld et al. (2020), Chesterman (2023))
#
# • "New Zealand's regulatory approach for AI will need to consider the implications for Māori and Te Tiriti o Waitangi." (SUPPORTED, Reference: AI and Te Ao Māori section)
#
# Overall verdict: The claims made in the response are generally supported by the provided reference, which suggests that the impact of artificial intelligence on the economy is multifaceted and can be understood through various frameworks.
#
# All claims supported. No refinement needed.
# Final Answer 1:
# The impact of artificial intelligence (AI) on the economy is multifaceted and can be understood through various frameworks. According to the provided reference, AI can be considered both a "General Purpose Technology" (GPT) and an "Invention of a Method of Invention" (IMI). A GPT has a wide range of applications, while an IMI raises productivity in the production of new ideas in research and innovation.
#
# From a macroeconomic perspective, AI can be thought of as a form of capital deepening, improving the quantity and quality of capital inputs. It can also be thought of as labor-augmenting technology that improves the quality of labor inputs.
#
# From a microeconomic perspective, AI can be seen as a form of workplace automation. A useful framework that summarizes the potential changes in the distribution and scope of tasks in production is presented by Acemoglu and Restrepo (2019). They identify three types of effects: the Displacement Effect, the Reinstatement Effect, and the Productivity Effect.
#
# Estimates suggest significant potential for productivity gains from AI, and from generative AI in particular. Briggs and Kodnani (2023) estimate that generative AI could increase labor productivity growth by 0.3 to 2.9 percentage points over ten years, with a central estimate of 1.5 points. Chui et al. (2023) suggest that generative AI could enable annual labor productivity growth of 0.1 to 0.6 percentage points annually from 2023 to 2040.
#
# However, the net impact of AI on labor demand and share depends on the balance between displacement and reinstatement. Briggs and Kodnani (2023) suggest that the short-term employment impacts might be modest, with around 7% of workers in the United States being fully displaced, but most finding new employment in only slightly less productive positions.
#
# Regarding regulatory approaches, there is a consensus on the principles that should govern AI, including human control, transparency, safety, accountability, non-discrimination, and privacy. New Zealand's regulatory approach for AI will need to consider the implications for Māori and Te Tiriti o Waitangi.
#
# The document also highlights the need for further research in areas such as policy levers to accelerate the diffusion of AI, the impacts of AI on the productivity and competitiveness of particular sectors, and the implications of AI for employment and labor markets.
#
#
# === Prompt 2 ===
# How will AI influence wage inequality globally?
#
#
# [Iteration 1 Validation Result]:
# • Acemoglu and Restrepo (2022) suggest that AI could contribute to further "so-so automation": SUPPORTED
#   • "So-so automation" refers to automation that reduces wages without significant productivity gains: SUPPORTED
#   • Acemoglu and Restrepo (2022) suggest that this type of automation is a potential contributor to the decline in wages since 1980 for workers in the United States without a high school degree: SUPPORTED
#
# Verdict: The claim is SUPPORTED by the reference.
#
# All claims supported. No refinement needed.
# Final Answer 2:
# The document states that Acemoglu and Restrepo (2022) suggest that AI could contribute to further "so-so automation", ie, automation that reduces wages without significant productivity gains. They suggest that this is a potential contributor to the decline in wages since 1980 for workers in the United States without a high school degree.
#
#
# === Prompt 3 ===
# What regulatory challenges are anticipated with AI adoption?
#
#
# [Iteration 1 Validation Result]:
# Here is the list of labelled claims:
#
# • The need to update existing regulatory frameworks, such as copyright laws, to address the challenges of AI: **SUPPORTED** (AN 24/06, p. 9)
# • The need to balance the benefits of AI with the need to protect human rights and prevent harm, particularly in areas such as data protection and algorithmic bias: **SUPPORTED** (AN 24/06, pp. 13-14)
# • The need for international regulatory harmonisation to support the diffusion of AI: **SUPPORTED** (AN 24/06, p. 16)
# • The need to consider the implications of AI for Māori and Te Tiriti o Waitangi (Te Tiriti), or the Treaty of Waitangi, given the extent of potential impacts on Māori rights and interests: **SUPPORTED** (AN 24/06, p. 16)
# • Generative AI tools may only draw on information from a limited number of cultures and generate results from them, marginalising a range of voices: **SUPPORTED** (AN 24/06, p. 16)
# • There is also the risk of algorithmic bias: **SUPPORTED** (AN 24/06, p. 16)
# • The implications of this for te reo Māori and taonga such as tā moko, haka and waiata are currently unknown: **SUPPORTED** (AN 24/06, p. 16)
# • The algorithm charter for Aotearoa New Zealand and the Office of the Privacy Commissioner have issued guidance to agencies, businesses and organisations using generative AI specifically: **SUPPORTED** (AN 24/06, p. 15)
#
# **Overall verdict:** All claims are supported by the reference document AN 24/06.
#
# All claims supported. No refinement needed.
# Final Answer 3:
# The reference document anticipates several regulatory challenges with AI adoption, including:
#
# * The need to update existing regulatory frameworks, such as copyright laws, to address the challenges of AI.
# * The need to balance the benefits of AI with the need to protect human rights and prevent harm, particularly in areas such as data protection and algorithmic bias.
# * The need for international regulatory harmonisation to support the diffusion of AI.
# * The need to consider the implications of AI for Māori and Te Tiriti o Waitangi (Te Tiriti), or the Treaty of Waitangi, given the extent of potential impacts on Māori rights and interests.
#
# Additionally, the document notes that New Zealand's regulatory approach for AI will need to consider the following:
#
# * Generative AI tools may only draw on information from a limited number of cultures and generate results from them, marginalising a range of voices.
# * There is also the risk of algorithmic bias.
# * The implications of this for te reo Māori and taonga such as tā moko, haka and waiata are currently unknown.
#
# The document also mentions that the algorithm charter for Aotearoa New Zealand and the Office of the Privacy Commissioner have issued guidance to agencies, businesses and organisations using generative AI specifically.
#
#
# === Prompt 4 ===
# How will AI adoption differ across regions and countries?
#
#
# [Iteration 1 Validation Result]:
# • Claim: Advanced economies like New Zealand might experience more substantial short-term productivity gains from AI.
#   Verdict: SUPPORTED (Reference: Briggs and Kodnani, 2023, as cited in the report)
#
# • Claim: Less developed economies may adopt AI more slowly due to various factors.
#   Verdict: SUPPORTED (Reference: Burns, 2009, as cited in the report)
#
# • Claim: The adoption of AI in less developed economies is hindered by factors such as access to foreign technology, the quality of government policy and institutions, the stock of human capital, and the financial system.
#   Verdict: SUPPORTED (Reference: Burns, 2009, as cited in the report)
#
# • Claim: The concentration of AI development in a small number of large multinational overseas-based technology companies might affect the adoption of AI in smaller countries like New Zealand.
#   Verdict: SUPPORTED (Reference: Bell, Burgess, Thomas, and Sadiq, 2023, as cited in the report)
#
# Overall verdict: The claims are supported by the references provided in the report, indicating that the adoption of AI can differ significantly across regions and countries due to various factors.
#
# All claims supported. No refinement needed.
# Final Answer 4:
# The adoption of AI is likely to differ across regions and countries due to various factors. For instance, advanced economies like New Zealand might experience more substantial short-term productivity gains from AI, while less developed economies may adopt AI more slowly due to factors such as access to foreign technology, the quality of government policy and institutions, the stock of human capital, and the financial system. Additionally, the concentration of AI development in a small number of large multinational overseas-based technology companies might affect the adoption of AI in smaller countries like New Zealand.
#
#
# === Prompt 5 ===
# What industries are most likely to be disrupted by AI according to the report?
#
#
# [Iteration 1 Validation Result]:
# * Briggs and Kodnani (2023) reported that industries like office support, legal, engineering, science, and business operations are most vulnerable to AI: SUPPORTED
# * Briggs and Kodnani (2023) reported that 35-46% of tasks in those industries are potentially automatable: SUPPORTED
#
# Verdict: The statement is accurate and supported by the reference.
#
# All claims supported. No refinement needed.
# Final Answer 5:
# Industries like office support, legal, engineering, science, and business operations are most vulnerable to AI, with 35-46% of tasks potentially automatable, as reported by Briggs and Kodnani (2023).
